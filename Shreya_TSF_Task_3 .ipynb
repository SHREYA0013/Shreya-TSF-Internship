# %% [markdown]
# # Author: Shreya Chakraborty
# ## Grip @The Sparks Foundation
# # Data Science and Business Analytics Intern
# ### Batch : December 2023

# %% [markdown]
# ## Task 3: Exploratory Data Analysis
# ### Dataset: SampleSuperstore

# %%
#Import libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Import CSV file:
df=pd.read_csv("C:/Users/shrey/Downloads/SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head(21)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# ...

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
print(df.isnull().sum())
print("There is no null values in the dataset")
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64
# There is no null values in the dataset

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
pd.isnull(df) #give us true false values
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %%
df.nunique() #unique values per column
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.duplicated().sum()
print("Duplicate values in our dataset: ",df.duplicated().sum())
# Out:
# Duplicate values in our dataset:  17

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df[["Sales","Profit"]].describe()
# Out:
#               Sales       Profit
# count   9994.000000  9994.000000
# mean     229.858001    28.656896
# std      623.245101   234.260108
# min        0.444000 -6599.978000
# 25%       17.280000     1.728750
# 50%       54.490000     8.666500
# 75%      209.940000    29.364000
# max    22638.480000  8399.976000

# %% [markdown]
# #### Data Visualization

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.hist(figsize=(30,25))
plt.show()

# %%
sns.pairplot(df,hue='Region')
plt.show
# Out:
# C:\PROGRAMMING\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df.isnull()) #Checking missing values
# Out:
# <Axes: >

# %% [markdown]
# ##### Correlation Matrix

# %%
correlation=df.corr(numeric_only=True)
print(correlation)
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(8, 6))
df.corr(numeric_only=True)
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
# Shipping Mode:

# %%
df["Ship Mode"].value_counts() #shipping mode wise
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='Ship Mode',data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show() #creating histograms

# %%
df['Ship Mode'].value_counts().plot(kind='pie',figsize=[5,5],autopct='%1.1f%%')
plt.title('Pie chart order distribution according to Shipping Mode')
# Out:
# Text(0.5, 1.0, 'Pie chart order distribution according to Shipping Mode')

# %% [markdown]
# ##### Standard Shipping mode is highly preferrable but Same Day is the least preferrable one

# %% [markdown]
# Segment:

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='Segment',data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df['Segment'].value_counts().plot(kind='pie',figsize=[5,5],autopct='%1.1f%%')
plt.title('Pie chart order distribution according to Segment')
# Out:
# Text(0.5, 1.0, 'Pie chart order distribution according to Segment')

# %% [markdown]
# ##### More people belongs to Consumer Class followed by Corporate  and Home Office

# %% [markdown]
# Country:

# %%
df['Country'].value_counts()
# Out:
# Country
# United States    9994
# Name: count, dtype: int64

# %% [markdown]
# ##### All orders are within United States

# %% [markdown]
# Category:

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='Category',data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df['Category'].value_counts().plot(kind='pie',figsize=[5,5],autopct='%1.1f%%')
plt.title('Pie chart order distribution according to Category')
# Out:
# Text(0.5, 1.0, 'Pie chart order distribution according to Category')

# %% [markdown]
# ##### Around 60% Categories belongs to Office Supplies , 21% belongs to Furniture and the rest 18.5% belongs to Technology

# %% [markdown]
# Sub Category:

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='Sub-Category',data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df['Sub-Category'].value_counts().plot(kind='pie',figsize=[15,15],autopct='%1.1f%%')
plt.title('Pie chart order distribution according to Sub-Category')
# Out:
# Text(0.5, 1.0, 'Pie chart order distribution according to Sub-Category')

# %% [markdown]
# City:

# %%
df['City'].value_counts()
# Out:
# City
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15, 6))
ax = sns.countplot(x='City', data=df, order=df['City'].value_counts().index[:10])
for bars in ax.containers:
    ax.bar_label(bars)
    print("Mostly ordered from")
plt.show()
# Out:
# Mostly ordered from

# %% [markdown]
# ##### New York city has the most orders followed by Los Angeles

# %%
fig, ax = plt.subplots(figsize=(15, 6))
ax = sns.countplot(x='City', data=df, order=df['City'].value_counts().index[-10:])
for bars in ax.patches:
    ax.annotate(f'{bars.get_height()}', (bars.get_x() + bars.get_width() / 2., bars.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
print("Least order placed from")
plt.show()
# Out:
# Least order placed from

# %% [markdown]
# State:

# %%
df['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 6))
ax = sns.countplot(x='State', data=df, order=df['State'].value_counts().index[:10])
for bars in ax.containers:
    ax.bar_label(bars)
    print("Mostly ordered from")
plt.show()
# Out:
# Mostly ordered from

# %% [markdown]
# ##### Most orders from California.

# %% [markdown]
# Region:

# %%
sns.countplot(x='Region',data=df)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %% [markdown]
# #### Count the sales region wise and found sales in highest in the western region and lowest in south.

# %%
ax=sns.countplot(x='Region',data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df['Region'].value_counts().plot(kind='pie',figsize=[12,7],autopct='%1.1f%%')
plt.title('Pie chart order distribution according to Region')
# Out:
# Text(0.5, 1.0, 'Pie chart order distribution according to Region')

# %% [markdown]
# ### Bivariate Analysis

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
regional_analysis=df.groupby("Region").sum(numeric_only=True)
print(regional_analysis)
# Out:
#          Postal Code        Sales  Quantity  Discount       Profit
# Region
# Central    151786150  501239.8908      8780    558.34   39706.3625
# East        50171698  678781.2400     10618    414.00   91522.7800
# South       55875052  391721.9050      6209    238.55   46749.4303
# West       293739752  725457.8245     12266    350.20  108418.4489

# %%
regional_analysis[['Sales','Profit']].plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
categorical_analysis=df.groupby("Category").sum(numeric_only=True)
print(categorical_analysis)
# Out:
#                  Postal Code        Sales  Quantity  Discount       Profit
# Category
# Furniture          118196026  741999.7953      8028    368.89   18451.2728
# Office Supplies    330772872  719047.0320     22906    947.80  122490.8008
# Technology         102603754  836154.0330      6939    244.40  145454.9481

# %%
categorical_analysis[['Sales','Profit']].plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
city_analysis=df.groupby("City").sum(numeric_only=True)
print(city_analysis)
# Out:
#              Postal Code     Sales  Quantity  Discount     Profit
# City
# Aberdeen           57401    25.500         3       0.0     6.6300
# Abilene            79605     1.392         2       0.8    -3.7584
# Akron             930552  2729.986        65       7.5  -186.6356
# Albuquerque      1219470  2220.160        65       0.8   634.0881
# Alexandria        356864  5519.570        84       0.0   318.6183
# ...                  ...       ...       ...       ...        ...
# Woonsocket         11580   195.550        15       0.0    78.6791
# Yonkers           160515  7657.666        57       1.0  2767.7557
# York               87015   817.978        19       2.1  -102.1692
# Yucaipa            92399    50.800         5       0.0    13.2080
# Yuma              341456   840.865        22       1.8  -465.9909
#
# [531 rows x 5 columns]

# %%
top_10_cities = city_analysis.nlargest(10, 'Sales')

top_10_cities[['Sales', 'Profit']].plot.bar()

plt.title('Top 10 Cities: Sales and Profit Analysis')
plt.xlabel('City')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# some of the cities have negative profit too

# %%
sub_categorical_analysis=df.groupby("Sub-Category").sum(numeric_only=True)
print(sub_categorical_analysis)
# Out:
#               Postal Code        Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories      44468434  167380.3180      2976     60.80  41936.6357
# Appliances       25250538  107532.1610      1729     77.60  18138.0054
# Art              43329658   27118.7920      3000     59.60   6527.7870
# Binders          83626398  203412.7330      5974    567.00  30221.7633
# Bookcases        12771539  114879.9963       868     48.14  -3472.5560
# Chairs           34936229  328449.1030      2356    105.00  26590.1663
# Copiers           3873477  149528.0300       234     11.00  55617.8249
# Envelopes        13325731   16476.4020       906     20.40   6964.1767
# Fasteners        12506063    3024.2800       914     17.80    949.5182
# Furnishings      51880430   91705.1640      3563    132.40  13059.1436
# Labels           19552985   12486.3120      1400     25.00   5546.2540
# Machines          6364668  189238.6310       440     35.20   3384.7569
# ...

# %%
sub_categorical_analysis[['Sales','Profit']].plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='Discount',y='Profit',data=df)
plt.title("Discount and Profit")
# Out:
# Text(0.5, 1.0, 'Discount and Profit')

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='Discount',y='Sales',data=df)
plt.title("Discount and Sales")
# Out:
# Text(0.5, 1.0, 'Discount and Sales')

# %% [markdown]
# #### When the store give discounts on product Sales increases but the profit decreases.
